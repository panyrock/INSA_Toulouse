# %%
# Calité d'aire

# %%
import folium 
import sys
import numpy
import pandas as pd
import numpy as np
from folium.plugins import MiniMap

# %%
capteur_grand = pd.read_csv(r"C:\Users\Barp9\OneDrive - Universidad Nacional de Colombia\INSA\4ème annee\Semestre 2\PIR\Calidad del aire mapa/capteur_grand.csv", sep=';')
capteur_grand
# Out:
#     Mesure   Latitude  Longitude  Temperature[°C]  Humidity[%]  Pressure[hPa]  \
# 0        1  43.573432   1.465524         7.859306    55.712612    1000.064872
# 1        2  43.572551   1.465786        12.778706    41.395738    1000.165938
# 2        3  43.572496   1.468773         9.734972    47.970695    1000.074776
# 3        4  43.570881   1.468642        11.152469    40.983438     999.553356
# 4        5  43.569916   1.469818        11.704516    40.432747     999.614216
# 5        6  43.568986   1.469259         9.691043    41.743740     999.717152
# 6        7  43.568010   1.470413         8.974186    43.594711     999.748911
# 7        8  43.568004   1.469266         8.948882    45.128634     999.735982
# 8        9  43.570399   1.468652        15.311574    37.462173     999.390986
# 9       10  43.569720   1.467627        13.507055    37.394070     999.501374
# 10      11  43.572206   1.467188        15.496098    36.675093     999.549690
# ...

# %%
##___opcion para matriz aun sin funcionar
#print (temperature_)
#df2 = pd.DataFrame()
#for c in df.columns:
 #   df2[c] = df[c]  
#print (df2)
#print (df2[0])
##___
# Opcion con array funcionando
# Carga de datos sensor grande
df = pd.DataFrame(capteur_grand)
latitude_grand= df['Latitude']
longitude_grand= df['Longitude']
particles1_grand= df['Particulates(1.0)[ug/m3]']
particles2_grand= df['Particulates(2.0)[ug/m3]']
particles10_grand= df['Particulates(10.0)[ug/m3]']
particles_NH3_grand = df["NH3[ug/m3]"]
#print (latitude_grand)

# %%
# Particulates(1.0)[ug/m3]
#insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], zoom_start=16) #Color
insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], tiles="Stamen Toner", zoom_start=16) #Blanco y negro
#folium.Circle(location=[43.57208226756045, 1.4648532071887355],color="purple",fill_color="red",radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)

for i in range(len(latitude_grand)):
    if particles1_grand[i] < 2:
        color_hexa = "#A5F720"
    elif particles1_grand[i] < 4:
        color_hexa = "#56ED1F"
    elif particles1_grand[i] < 6:
        color_hexa = "#D9E028"
    elif particles1_grand[i] < 8:
        color_hexa = "#F7E420"
    else:
        color_hexa = "#F89957"
    folium.Circle(location=[latitude_grand[i],longitude_grand[i]],color="purple",fill_color=color_hexa,radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)


insa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Particulates(2.0)[ug/m3]
#insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], zoom_start=16) #Color
insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], tiles="Stamen Toner", zoom_start=16) #Blanco y negro
#folium.Circle(location=[43.57208226756045, 1.4648532071887355],color="purple",fill_color="red",radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)

for i in range(len(latitude_grand)):
    if particles2_grand[i] < 2:
        color_hexa = "#A5F720"
    elif particles2_grand[i] < 4:
        color_hexa = "#56ED1F"
    elif particles2_grand[i] < 6:
        color_hexa = "#D9E028"
    elif particles2_grand[i] < 8:
        color_hexa = "#F7E420"
    else:
        color_hexa = "#F89957"
    folium.Circle(location=[latitude_grand[i],longitude_grand[i]],color="purple",fill_color=color_hexa,radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)


insa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Particulates(2.0)[ug/m3]
#insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], zoom_start=16) #Color
insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], tiles="Stamen Toner", zoom_start=16) #Blanco y negro
#folium.Circle(location=[43.57208226756045, 1.4648532071887355],color="purple",fill_color="red",radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)

for i in range(len(latitude_grand)):
    if particles2_grand[i] < 2:
        color_hexa = "#A5F720"
    elif particles2_grand[i] < 4:
        color_hexa = "#56ED1F"
    elif particles2_grand[i] < 6:
        color_hexa = "#D9E028"
    elif particles2_grand[i] < 8:
        color_hexa = "#F7E420"
    else:
        color_hexa = "#F89957"
    folium.Circle(location=[latitude_grand[i],longitude_grand[i]],color="purple",fill_color=color_hexa,radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)


insa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Particulates(10.0)[ug/m3]
#insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], zoom_start=16) #Color
insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], tiles="Stamen Toner", zoom_start=16) #Blanco y negro
#folium.Circle(location=[43.57208226756045, 1.4648532071887355],color="purple",fill_color="red",radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)

for i in range(len(latitude_grand)):
    if particles10_grand[i] < 2:
        color_hexa = "#A5F720"
    elif particles10_grand[i] < 4:
        color_hexa = "#56ED1F"
    elif particles10_grand[i] < 6:
        color_hexa = "#D9E028"
    elif particles10_grand[i] < 8:
        color_hexa = "#F7E420"
    else:
        color_hexa = "#F89957"
    folium.Circle(location=[latitude_grand[i],longitude_grand[i]],color="purple",fill_color=color_hexa,radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)


insa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Particulates(NH3)[ug/m3]
#insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], zoom_start=16) #Color
insa_map = folium.Map(location=[43.569861717907294, 1.4677892622642483], tiles="Stamen Toner", zoom_start=16) #Blanco y negro
#folium.Circle(location=[43.57208226756045, 1.4648532071887355],color="purple",fill_color="red",radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)

for i in range(len(latitude_grand)):
    if particles_NH3_grand[i] < 200:
        color_hexa = "#A5F720"
    elif particles_NH3_grand[i] < 400:
        color_hexa = "#56ED1F"
    elif particles_NH3_grand[i] < 600:
        color_hexa = "#D9E028"
    elif particles_NH3_grand[i] < 800:
        color_hexa = "#F7E420"
    else:
        color_hexa = "#F89957"
    folium.Circle(location=[latitude_grand[i],longitude_grand[i]],color="purple",fill_color=color_hexa,radius=20,weight=0,fill_opacity=0.3).add_to(insa_map)

print (color_hexa)
insa_map
# Out:
# #F7E420
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
capteur_petit = pd.read_csv(r"C:\Users\Barp9\OneDrive - Universidad Nacional de Colombia\INSA\4ème annee\Semestre 2\PIR\Calidad del aire mapa/capteur_petit.csv", sep=';')
capteur_petit
# Out:
#     Mesure  Latitude  Longitude  Temperature[°C]  Humidity[%]  Pressure[hPa]  \
# 0        1       NaN        NaN        14.271508    61.299079    1000.511925
# 1        2       NaN        NaN        18.846009    49.917826    1001.760930
# 2        3       NaN        NaN        15.882850    54.011008    1001.226146
# 3        4       NaN        NaN        18.076460    49.425581    1000.203925
# 4        5       NaN        NaN        16.737274    52.472119    1000.621155
# 5        6       NaN        NaN        17.752256    50.180194    1000.390394
# 6        7       NaN        NaN        16.430953    52.065233    1000.570079
# 7        8       NaN        NaN        16.095306    52.752608    1000.488228
# 8        9       NaN        NaN        20.764771    44.884201     999.983626
# 9       10       NaN        NaN        19.402605    47.513239    1000.232403
# 10      11       NaN        NaN        17.378501    56.046701    1000.336485
# ...
